# %%
from IPython.display import Image
Image(filename ="missing.jpeg", width=800, height=800)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../aula8/data/aluguel_residencial.csv', sep=';')
df.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# 4         NaN   NaN

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# IPTU          6785
# Condominio    1815
# Valor            9
# Area             0
# Suites           0
# Vagas            0
# Quartos          0
# Bairro           0
# Tipo             0
# dtype: int64

# %%
df[df['Valor'].isnull()][:10]
# Out:
#              Tipo           Bairro  Quartos  Vagas  Suites  Area  Valor  \
# 58    Apartamento  Barra da Tijuca        2      1       1    70    NaN
# 1492  Apartamento             Leme        2      0       0    75    NaN
# 1683         Casa     Campo Grande        3      4       3   363    NaN
# 2012  Apartamento         Botafogo        2      0       0    95    NaN
# 2034  Apartamento       Copacabana        2      0       0    72    NaN
# 4941         Casa     Campo Grande        3      2       1   100    NaN
# 8568  Apartamento             Leme        2      0       1    75    NaN
# 8947  Apartamento           Glória        3      0       1   135    NaN
# 9149  Apartamento            Gávea        3      1       1   105    NaN
#
#       Condominio   IPTU
# 58         970.0   68.0
# 1492       878.0    NaN
# 1683         NaN    NaN
# 2012      1010.0  170.0
# 2034       850.0    NaN
# 4941         NaN    NaN
# 8568       878.0    NaN
# 8947       910.0  228.0
# ...

# %%
df[df['Condominio'].isnull()].shape[0]
# Out:
# 1815

# %%
df.fillna(0, inplace=True)
df.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         0.0   0.0
# 2       390.0  20.0
# 3       230.0   0.0
# 4         0.0   0.0

# %%
df[df['Condominio'].isnull()].shape[0]
# Out:
# 0

# %%
df.Bairro.value_counts()
# Out:
# Barra da Tijuca                   3922
# Copacabana                        2760
# Ipanema                           1800
# Recreio dos Bandeirantes          1672
# Leblon                            1277
# Tijuca                            1113
# Botafogo                           890
# Flamengo                           723
# Campo Grande                       535
# Lagoa                              494
# Freguesia (Jacarepaguá)            461
# Laranjeiras                        428
# Centro                             348
# Vila Isabel                        304
# Jardim Botânico                    266
# Méier                              262
# São Conrado                        261
# Jacarepaguá                        247
# Leme                               234
# Gávea                              216
# Pechincha                          204
# Taquara                            181
# Catete                             162
# Humaitá                            159
# ...

# %%
df.sort_values(by='Valor', ascending=False)[:10]
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 16056         Apartamento                  Botafogo        4      1       1
# 14325         Apartamento  Recreio dos Bandeirantes        3      2       1
# 11013  Casa de Condomínio   Freguesia (Jacarepaguá)        4      2       3
# 7894          Apartamento           Barra da Tijuca        1      1       0
# 13099         Apartamento   Freguesia (Jacarepaguá)        2      2       1
# 22152         Apartamento           Barra da Tijuca        4      3       4
# 20521         Apartamento                    Leblon        3      1       2
# 10186         Apartamento                   Ipanema        5      3       4
# 5022          Apartamento                   Ipanema        5      3       4
# 21911         Apartamento                   Ipanema        3      3       3
#
#        Area      Valor  Condominio     IPTU
# 16056   300  4500000.0      1100.0      0.0
# ...

# %%
df.loc[df['Bairro'] == 'Cachamorra']
# Out:
#                     Tipo      Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 9688  Casa de Condomínio  Cachamorra        3      5       3   250  3000.0
#
#       Condominio   IPTU
# 9688       200.0  180.0

# %%
df.loc[df['Valor'] <= 1000][:10]
# Out:
#                   Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 2          Apartamento                   Centro        1      0       0    15
# 3          Apartamento             Higienópolis        1      0       0    48
# 7   Casa de Condomínio                    Ramos        2      2       0    65
# 15         Apartamento  Freguesia (Jacarepaguá)        3      0       0    54
# 19         Apartamento                   Olaria        3      1       0    68
# 22         Apartamento                   Tijuca        1      0       0    48
# 40         Apartamento                   Centro        1      0       0    27
# 58         Apartamento          Barra da Tijuca        2      1       1    70
# 59         Apartamento                 Cachambi        2      0       0    60
# 65         Apartamento           Vila Valqueire        2      1       0    45
#
#      Valor  Condominio   IPTU
# 2    800.0       390.0   20.0
# 3    800.0       230.0    0.0
# ...

# %%
df.loc[(df['Valor'] <= 1000) & (df['Condominio'] <= 500)][:10]
# Out:
#                    Tipo                   Bairro  Quartos  Vagas  Suites  \
# 2           Apartamento                   Centro        1      0       0
# 3           Apartamento             Higienópolis        1      0       0
# 7    Casa de Condomínio                    Ramos        2      2       0
# 15          Apartamento  Freguesia (Jacarepaguá)        3      0       0
# 40          Apartamento                   Centro        1      0       0
# 59          Apartamento                 Cachambi        2      0       0
# 65          Apartamento           Vila Valqueire        2      1       0
# 78          Apartamento                Itanhangá        2      1       0
# 83          Apartamento               Praça Seca        2      0       0
# 106         Apartamento               Praça Seca        2      0       0
#
#      Area   Valor  Condominio   IPTU
# 2      15   800.0       390.0   20.0
# 3      48   800.0       230.0    0.0
# 7      65  1000.0         0.0    0.0
# ...

# %%
df.loc[(df['Tipo'] == 'Apartamento') & (df['Quartos'] == 4)][:10]
# Out:
#             Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 13   Apartamento               Copacabana        4      3       1   243
# 33   Apartamento               Copacabana        4      1       0   244
# 45   Apartamento          Barra da Tijuca        4      3       3   153
# 46   Apartamento                Península        4      3       4   267
# 63   Apartamento          Barra da Tijuca        4      4       4   240
# 87   Apartamento  Freguesia (Jacarepaguá)        4      3       2   261
# 97   Apartamento          Barra da Tijuca        4      3       2   220
# 116  Apartamento          Barra da Tijuca        4      2       3   320
# 120  Apartamento                   Leblon        4      4       4   380
# 124  Apartamento                 Botafogo        4      1       1   190
#
#        Valor  Condominio    IPTU
# 13   13000.0      2000.0   803.0
# 33    5000.0      2500.0  4100.0
# 45    6500.0      2300.0   434.0
# 46   18000.0      3100.0   400.0
# ...

# %%
df['Area'].min()
# Out:
# 10

# %%
# Criar uma função para caracterização

def categoriza(inv):
    if inv >= 1500:
        return 'Big'
    elif (inv >= 600) and (inv < 1500):
        return 'Medium'
    elif inv < 600:
        return 'Small'

# %%
df['cat_size'] = df['Area'].apply(categoriza)
df.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU cat_size
# 0       500.0  60.0    Small
# 1         0.0   0.0    Small
# 2       390.0  20.0    Small
# 3       230.0   0.0    Small
# 4         0.0   0.0    Small

# %%
df.cat_size.value_counts()
# Out:
# Small     22064
# Medium      501
# Big          15
# Name: cat_size, dtype: int64

# %%
df[df['Bairro'] == 'Abolição']
# Out:
#                Tipo    Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 1596   Casa de Vila  Abolição        2      0       0    68  1200.0
# 3283    Apartamento  Abolição        2      2       0    81   850.0
# 6883           Casa  Abolição        1      0       0    50  1100.0
# 7190    Apartamento  Abolição        2      1       0    65  1300.0
# 7899    Apartamento  Abolição        2      0       0    50  1000.0
# 10167   Apartamento  Abolição        2      0       0    65  1200.0
# 10500  Casa de Vila  Abolição        2      0       0    68  1200.0
# 13617   Apartamento  Abolição        2      0       0    45  1200.0
# 14679   Apartamento  Abolição        2      0       0    43   800.0
# 16608   Apartamento  Abolição        2      1       0    44   900.0
# 17210          Casa  Abolição        2      3       0    80  2300.0
# 17733          Casa  Abolição        2      0       0   360  2000.0
# 19450   Apartamento  Abolição        2      0       0    48   900.0
# ...

# %%
df.groupby('Bairro').get_group('Abolição')
# Out:
#                Tipo    Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 1596   Casa de Vila  Abolição        2      0       0    68  1200.0
# 3283    Apartamento  Abolição        2      2       0    81   850.0
# 6883           Casa  Abolição        1      0       0    50  1100.0
# 7190    Apartamento  Abolição        2      1       0    65  1300.0
# 7899    Apartamento  Abolição        2      0       0    50  1000.0
# 10167   Apartamento  Abolição        2      0       0    65  1200.0
# 10500  Casa de Vila  Abolição        2      0       0    68  1200.0
# 13617   Apartamento  Abolição        2      0       0    45  1200.0
# 14679   Apartamento  Abolição        2      0       0    43   800.0
# 16608   Apartamento  Abolição        2      1       0    44   900.0
# 17210          Casa  Abolição        2      3       0    80  2300.0
# 17733          Casa  Abolição        2      0       0   360  2000.0
# 19450   Apartamento  Abolição        2      0       0    48   900.0
# ...

# %%
df.groupby('cat_size').get_group('Big')
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 44     Casa de Condomínio  Barra da Tijuca        5     10       5  1600
# 3214   Casa de Condomínio  Barra da Tijuca        5      3       3  1750
# 3560   Casa de Condomínio            Gávea        6     10       6  1500
# 5699   Casa de Condomínio        Itanhangá        4      8       4  1800
# 7357                 Casa  Jardim Botânico        5      4       4  2252
# 10355                Casa      Jacarepaguá        8     20       7  2000
# 12433  Casa de Condomínio  Barra da Tijuca        4      4       4  2070
# 12501  Casa de Condomínio              Joá        6      3       6  1900
# 13818  Casa de Condomínio  Barra da Tijuca        5     10       5  2000
# 14275  Casa de Condomínio  Barra da Tijuca        6      6       6  1621
# 15777  Casa de Condomínio  Barra da Tijuca        6     10       4  1700
# 18189  Casa de Condomínio            Gávea        6      3       6  1500
# ...

# %%
df.groupby('cat_size').last()
# Out:
#                         Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# cat_size
# Big                     Casa      São Conrado        4      5       3  3000
# Medium    Casa de Condomínio  Barra da Tijuca        3      5       3  1000
# Small            Apartamento           Leblon        2      0       0    70
#
#             Valor  Condominio    IPTU
# cat_size
# Big       22000.0      2700.0  1700.0
# Medium    20000.0      3000.0     0.0
# Small      3000.0       760.0     0.0

# %%
df.groupby('cat_size').first()
# Out:
#                         Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# cat_size
# Big       Casa de Condomínio  Barra da Tijuca        5     10       5  1600
# Medium    Casa de Condomínio  Barra da Tijuca        5      4       5   750
# Small              Quitinete       Copacabana        1      0       0    40
#
#             Valor  Condominio  IPTU
# cat_size
# Big       25000.0      1600.0   0.0
# Medium    22000.0         0.0   0.0
# Small      1700.0       500.0  60.0

# %%
df.groupby('cat_size').nth(-2)
# Out:
#                         Tipo                Bairro  Quartos  Vagas  Suites  \
# cat_size
# Big       Casa de Condomínio             Itanhangá        5      8       5
# Medium    Casa de Condomínio       Barra da Tijuca        4      4       2
# Small            Apartamento  São Francisco Xavier        2      1       0
#
#           Area    Valor  Condominio   IPTU
# cat_size
# Big       2200  25000.0      1300.0  345.0
# Medium     600  30000.0      1050.0    0.0
# Small       48   1400.0       509.0   37.0

# %%
df.groupby('cat_size').groups
# Out:
# {'Big': Int64Index([   44,  3214,  3560,  5699,  7357, 10355, 12433, 12501, 13818,
#              14275, 15777, 18189, 19846, 21392, 21677],
#             dtype='int64'),
#  'Medium': Int64Index([    6,    60,   126,   217,   261,   269,   275,   308,   368,
#                572,
#              ...
#              22240, 22250, 22281, 22289, 22292, 22315, 22368, 22444, 22464,
#              22555],
#             dtype='int64', length=501),
#  'Small': Int64Index([    0,     1,     2,     3,     4,     5,     7,     8,     9,
#                 10,
#              ...
#              22570, 22571, 22572, 22573, 22574, 22575, 22576, 22577, 22578,
#              22579],
#             dtype='int64', length=22064)}

# %%
df.groupby('cat_size').size()
# Out:
# cat_size
# Big          15
# Medium      501
# Small     22064
# dtype: int64

# %%
df.groupby('cat_size').agg({'Condominio':'count',
                           'Valor':'mean'})
# Out:
#           Condominio         Valor
# cat_size
# Big               15  25900.000000
# Medium           501  21140.007984
# Small          22064   4602.668193

# %%
df.groupby('Tipo').agg({'Condominio':'count',
                           'Valor':'mean'})
# Out:
#                     Condominio         Valor
# Tipo
# Apartamento              19532   4742.914243
# Casa                       967   6779.404343
# Casa de Condomínio         996  11952.061245
# Casa de Vila               249   1574.369478
# Quitinete                  836   1246.840909

# %%
df.groupby('Tipo').agg(['sum','mean'])
# Out:
#                    Quartos            Vagas           Suites            \
#                        sum      mean    sum      mean    sum      mean
# Tipo
# Apartamento          48470  2.481569  24071  1.232388  17110  0.875998
# Casa                  3030  3.133402   1736  1.795243   1217  1.258532
# Casa de Condomínio    3991  4.007028   3089  3.101406   2853  2.864458
# Casa de Vila           480  1.927711     97  0.389558     57  0.228916
# Quitinete              698  0.834928     15  0.017943     31  0.037081
#
#                        Area                   Valor                Condominio  \
#                         sum        mean         sum          mean         sum
# Tipo
# Apartamento         2339748  119.790498  92638601.0   4742.914243  32363495.0
# Casa                 242309  250.578077   6555684.0   6779.404343    195569.0
# Casa de Condomínio   454337  456.161647  11904253.0  11952.061245   1209165.0
# ...

# %%
df.groupby('Bairro')[['Quartos', 'Valor']].sum()
# Out:
#                       Quartos       Valor
# Bairro
# Abolição                   30     19130.0
# Alto da Boa Vista          22     23800.0
# Anchieta                   13      5490.0
# Andaraí                   193    143377.0
# Anil                      190    151040.0
# Arpoador                   33    161587.0
# Bancários                   9      7300.0
# Bangu                      47     23970.0
# Barra da Tijuca         11953  27736063.0
# Barra de Guaratiba         12     22200.0
# Benfica                    14      6330.0
# Bento Ribeiro              39     24310.0
# Bonsucesso                145     82830.0
# Botafogo                 1916   7726266.0
# Braz de Pina               51     28150.0
# Cachambi                  275    160197.0
# Cachamorra                  3      3000.0
# Cacuia                      3      2750.0
# Caju                        1       850.0
# Camorim                   118     76350.0
# Campinho                   31     16160.0
# ...

# %%
df.groupby(by=df['Tipo']).Bairro.value_counts()
# Out:
# Tipo         Bairro
# Apartamento  Barra da Tijuca             3341
#              Copacabana                  2465
#              Ipanema                     1768
#              Recreio dos Bandeirantes    1490
#              Leblon                      1241
#              Tijuca                      1059
#              Botafogo                     788
#              Flamengo                     647
#              Lagoa                        487
#              Freguesia (Jacarepaguá)      397
#              Laranjeiras                  389
#              Campo Grande                 319
#              Vila Isabel                  277
#              Méier                        234
#              São Conrado                  233
#              Jacarepaguá                  226
#              Leme                         223
#              Jardim Botânico              210
#              Centro                       204
#              Pechincha                    184
# ...

# %%
grouped = df[['Valor','Bairro']].groupby(df['Tipo'])
grouped.max()
# Out:
#                         Valor         Bairro
# Tipo
# Apartamento         4500000.0     Água Santa
# Casa                  60000.0     Água Santa
# Casa de Condomínio   800000.0   Vista Alegre
# Casa de Vila          15000.0     Água Santa
# Quitinete              6500.0  Vila da Penha

# %%
# %time
grouped.Bairro.describe()
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 7.15 µs
#                     count unique              top  freq
# Tipo
# Apartamento         19532    149  Barra da Tijuca  3341
# Casa                  967    114     Campo Grande   170
# Casa de Condomínio    996     60  Barra da Tijuca   496
# Casa de Vila          249     80           Tijuca    15
# Quitinete             836     53       Copacabana   290

# %%
df.to_csv('../aula9/data/aluguel_residencial2.csv', sep=';', index=False)

# %%
dados = pd.read_csv('../aula9/data/aluguel_residencial2.csv', sep=';')
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU cat_size
# 0       500.0  60.0    Small
# 1         0.0   0.0    Small
# 2       390.0  20.0    Small
# 3       230.0   0.0    Small
# 4         0.0   0.0    Small

# %%
# Qual o valor bruto mensal a ser pago pelo inquilino?

dados['Valor_mes'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU cat_size  Valor_mes
# 0       500.0  60.0    Small     2260.0
# 1         0.0   0.0    Small     7000.0
# 2       390.0  20.0    Small     1210.0
# 3       230.0   0.0    Small     1030.0
# 4         0.0   0.0    Small     1200.0

# %%
# Quanto custa o metro quadrado?

dados['Metro_Q'] = (dados['Valor'] / dados['Area']).round(2)
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU cat_size  Valor_mes  Metro_Q  Valor_mes_Q
# 0       500.0  60.0    Small     2260.0    42.50        56.50
# 1         0.0   0.0    Small     7000.0    70.00        70.00
# 2       390.0  20.0    Small     1210.0    53.33        80.67
# 3       230.0   0.0    Small     1030.0    16.67        21.46
# 4         0.0   0.0    Small     1200.0    17.14        17.14

# %%
# Valor do metro quadrado por mês

dados['Valor_mes_Q'] = (dados['Valor_mes'] / dados['Area']).round(2)
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU cat_size  Valor_mes  Metro_Q  Valor_mes_Q
# 0       500.0  60.0    Small     2260.0    42.50        56.50
# 1         0.0   0.0    Small     7000.0    70.00        70.00
# 2       390.0  20.0    Small     1210.0    53.33        80.67
# 3       230.0   0.0    Small     1030.0    16.67        21.46
# 4         0.0   0.0    Small     1200.0    17.14        17.14

# %%
dados['Tipo'].value_counts()
# Out:
# Apartamento           19532
# Casa de Condomínio      996
# Casa                    967
# Quitinete               836
# Casa de Vila            249
# Name: Tipo, dtype: int64

# %%
df.groupby('Tipo').get_group('Casa')
# Out:
#        Tipo                    Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 1      Casa           Jardim Botânico        2      0       1   100   7000.0
# 24     Casa              Campo Grande        4      1       2   400  12000.0
# 56     Casa                     Méier        2      0       0    51   1500.0
# 60     Casa               São Conrado        4      2       4   730  28000.0
# 100    Casa                  Maracanã        8      3       5   259   7000.0
# 104    Casa                   Benfica        1      0       0    33   1200.0
# 150    Casa            Jardim Carioca        3      2       1   135   3000.0
# 166    Casa       Lins de Vasconcelos        2      0       0    40    950.0
# 188    Casa                    Tijuca        4      1       1   191   4000.0
# 248    Casa                    Grajaú        5      4       2   450   7000.0
# 260    Casa                    Tanque        2      1       0    59   1200.0
# ...

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados['Tipo Residencia'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU cat_size  Valor_mes  Metro_Q  Valor_mes_Q Tipo Residencia
# 0       500.0  60.0    Small     2260.0    42.50        56.50     Apartamento
# 1         0.0   0.0    Small     7000.0    70.00        70.00            Casa
# 2       390.0  20.0    Small     1210.0    53.33        80.67     Apartamento
# 3       230.0   0.0    Small     1030.0    16.67        21.46     Apartamento
# 4         0.0   0.0    Small     1200.0    17.14        17.14     Apartamento

# %%
dados['Bairro'].unique()
# Out:
# array(['Copacabana', 'Jardim Botânico', 'Centro', 'Higienópolis',
#        'Vista Alegre', 'Cachambi', 'Barra da Tijuca', 'Ramos', 'Grajaú',
#        'Lins de Vasconcelos', 'Taquara', 'Freguesia (Jacarepaguá)',
#        'Tijuca', 'Olaria', 'Ipanema', 'Campo Grande', 'Botafogo',
#        'Recreio dos Bandeirantes', 'Leblon', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'São Conrado', 'Vila Valqueire', 'Gávea', 'Cosme Velho',
#        'Bonsucesso', 'Todos os Santos', 'Laranjeiras', 'Itanhangá',
#        'Flamengo', 'Praça Seca', 'Piedade', 'Lagoa', 'Catete',
#        'Jardim Carioca', 'Benfica', 'Glória', 'Vila Isabel',
#        'Rocha Miranda', 'Engenho Novo', 'Engenho de Dentro',
#        'Cidade Nova', 'Pilares', 'Tomás Coelho', 'Água Santa',
#        'São Cristóvão', 'Ilha do Governador', 'Jardim Sulacap',
#        'Oswaldo Cruz', 'Vila da Penha', 'Anil', 'Vargem Grande', 'Tanque',
# ...

# %%
bairros = ['Copacabana', 'Jardim Botânico', 'Centro', 'Higienópolis',
       'Vista Alegre', 'Cachambi', 'Barra da Tijuca', 'Ramos', 'Grajaú',
       'Lins de Vasconcelos', 'Taquara', 'Freguesia (Jacarepaguá)',
       'Tijuca', 'Olaria', 'Ipanema', 'Campo Grande', 'Botafogo',
       'Recreio dos Bandeirantes', 'Leblon', 'Jardim Oceânico', 'Humaitá',
       'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
       'São Conrado', 'Vila Valqueire', 'Gávea', 'Cosme Velho',
       'Bonsucesso', 'Todos os Santos', 'Laranjeiras', 'Itanhangá',
       'Flamengo', 'Praça Seca', 'Piedade', 'Lagoa', 'Catete',
       'Jardim Carioca', 'Benfica', 'Glória', 'Vila Isabel',
       'Rocha Miranda', 'Engenho Novo', 'Engenho de Dentro',
       'Cidade Nova', 'Pilares', 'Tomás Coelho', 'Água Santa',
       'São Cristóvão', 'Ilha do Governador', 'Jardim Sulacap',
       'Oswaldo Cruz', 'Vila da Penha', 'Anil', 'Vargem Grande', 'Tanque',
       'Vaz Lobo', 'Madureira', 'São Francisco Xavier', 'Pechincha',
       'Leme', 'Irajá', 'Quintino Bocaiúva', 'Urca', 'Penha',
       'Gardênia Azul', 'Rio Comprido', 'Andaraí', 'Santa Teresa',
       'Inhaúma', 'Marechal Hermes', 'Curicica', 'Santíssimo', 'Moneró',
       'Jardim Guanabara', 'Camorim', 'Cascadura', 'Praia da Bandeira',
       'Saúde', 'Joá', 'Colégio', 'Guadalupe', 'Realengo', 'Fátima',
       'Inhoaíba', 'Rocha', 'Jabour', 'Braz de Pina',
       'Vicente de Carvalho', 'Praça da Bandeira', 'Vila Kosmos',
       'Encantado', 'Campinho', 'Ricardo de Albuquerque', 'Guaratiba',
       'Riachuelo', 'Bangu', 'Lapa', 'Catumbi', 'Penha Circular',
       'Parque Anchieta', 'Abolição', 'Pavuna', 'Santa Cruz',
       'Alto da Boa Vista', 'Bento Ribeiro', 'Estácio', 'Jardim América',
       'Cordovil', 'Caju', 'Pedra de Guaratiba', 'Padre Miguel',
       'Paciência', 'Del Castilho', 'Arpoador', 'Sampaio', 'Anchieta',
       'Icaraí', 'Senador Vasconcelos', 'Gamboa', 'Maria da Graça',
       'Barra de Guaratiba', 'Paquetá', 'Largo do Machado',
       'Parada de Lucas', 'Turiaçu', 'Freguesia (Ilha do Governador)',
       'Portuguesa', 'Honório Gurgel', 'Santo Cristo', 'Pitangueiras',
       'Vila Militar', 'Vidigal', 'Senador Camará', 'Usina',
       'Vigário Geral', 'Cosmos', 'Jacaré', 'Cocotá', 'Engenho da Rainha',
       'Cachamorra', 'Zumbi', 'Tauá', 'Ribeira', 'Magalhães Bastos',
       'Cacuia', 'Bancários', 'Cavalcanti', 'Rio da Prata',
       'Cidade Jardim', 'Coelho Neto', 'Grumari']

# %%
select = dados['Bairro'].isin(bairros)
dados = dados[select]
dados['Bairro'].drop_duplicates()
# Out:
# 0                            Copacabana
# 1                       Jardim Botânico
# 2                                Centro
# 3                          Higienópolis
# 4                          Vista Alegre
# 5                              Cachambi
# 6                       Barra da Tijuca
# 7                                 Ramos
# 9                                Grajaú
# 10                  Lins de Vasconcelos
# 14                              Taquara
# 15              Freguesia (Jacarepaguá)
# 17                               Tijuca
# 19                               Olaria
# 21                              Ipanema
# 24                         Campo Grande
# 25                             Botafogo
# 28             Recreio dos Bandeirantes
# 29                               Leblon
# 31                      Jardim Oceânico
# 38                              Humaitá
# 46                            Península
# 48                                Méier
# ...

# %%
grupo1 = dados.groupby('Bairro')

# %%
grupo1.groups
# Out:
# {'Abolição': Int64Index([ 1596,  3283,  6883,  7190,  7899, 10167, 10500, 13617, 14679,
#              16608, 17210, 17733, 19450, 19458, 20802, 22130],
#             dtype='int64'),
#  'Alto da Boa Vista': Int64Index([2270, 12452, 12988, 13699, 13905, 15018], dtype='int64'),
#  'Anchieta': Int64Index([3112, 8511, 9188, 13062, 16012, 16198, 18434], dtype='int64'),
#  'Andaraí': Int64Index([  395,   464,   529,   631,   813,   870,   878,  1026,  1225,
#               1455,  1460,  1735,  1968,  2076,  2205,  2764,  3234,  3315,
#               3598,  3691,  3860,  3982,  4365,  4721,  4927,  5035,  5042,
#               5122,  5731,  5947,  6193,  6444,  6669,  6753,  7150,  7417,
#               7667,  8162,  8163,  8342,  8723,  9506,  9611,  9655,  9706,
#              10059, 10279, 10463, 10622, 10643, 11241, 11324, 11331, 11467,
#              11918, 12227, 12714, 13202, 13703, 13850, 13854, 14247, 14377,
# ...

# %%
for bairros, dados in grupo1:
    print(dados)
# Out:
#                Tipo    Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 1596   Casa de Vila  Abolição        2      0       0    68  1200.0
# 3283    Apartamento  Abolição        2      2       0    81   850.0
# 6883           Casa  Abolição        1      0       0    50  1100.0
# 7190    Apartamento  Abolição        2      1       0    65  1300.0
# 7899    Apartamento  Abolição        2      0       0    50  1000.0
# 10167   Apartamento  Abolição        2      0       0    65  1200.0
# 10500  Casa de Vila  Abolição        2      0       0    68  1200.0
# 13617   Apartamento  Abolição        2      0       0    45  1200.0
# 14679   Apartamento  Abolição        2      0       0    43   800.0
# 16608   Apartamento  Abolição        2      1       0    44   900.0
# 17210          Casa  Abolição        2      3       0    80  2300.0
# 17733          Casa  Abolição        2      0       0   360  2000.0
# 19450   Apartamento  Abolição        2      0       0    48   900.0
# ...

# %%
for bairros, dados in grupo1:
    print('{} -> {}'.format(bairros, dados['Valor'].mean()))
# Out:
# Abolição -> 1195.625
# Alto da Boa Vista -> 3966.6666666666665
# Anchieta -> 784.2857142857143
# Andaraí -> 1463.030612244898
# Anil -> 1987.3684210526317
# Arpoador -> 12429.76923076923
# Bancários -> 1825.0
# Bangu -> 998.75
# Barra da Tijuca -> 7071.9181540030595
# Barra de Guaratiba -> 5550.0
# Benfica -> 904.2857142857143
# Bento Ribeiro -> 1012.9166666666666
# Bonsucesso -> 1218.0882352941176
# Botafogo -> 8681.197752808988
# Braz de Pina -> 1082.6923076923076
# Cachambi -> 1169.3211678832117
# Cachamorra -> 3000.0
# Cacuia -> 916.6666666666666
# Caju -> 850.0
# Camorim -> 1735.2272727272727
# Campinho -> 1010.0
# Campo Grande -> 1192.2878504672897
# Cascadura -> 1054.2105263157894
# Catete -> 2271.1728395061727
# Catumbi -> 1177.7777777777778
# Cavalcanti -> 663.3333333333334
# Centro -> 1355.4022988505747
# Cidade Jardim -> 12000.0
# Cidade Nova -> 1400.0
# Cocotá -> 1883.3333333333333
# Coelho Neto -> 700.0
# Colégio -> 903.3333333333334
# Copacabana -> 4135.914492753624
# ...

# %%
'''
Suponha que estejamos testando as moedas que serão utilizadas por árbitros de futebol nas competições da Copa 
do Mundo. Atualmente, estas moedas são personalizadas e utilizadas em certos momentos dos jogos para decidir, 
na sorte, uma disputa. 

Nosso objetivo é verificar se as moedas que serão utilizadas nas competições não sejam viciadas.
Para isso testes foram realizados com cinco moedas e os resultados foram os seguintes:
'''

m1 = 'CCcCCccCCCccCcCccCcCcCCCcCCcccCCcCcCcCcccCCcCcccCc'
m2 = 'CCCCCccCccCcCCCCccCccccCccCccCCcCccCcCcCCcCccCccCc'
m3 = 'CccCCccCcCCCCCCCCCCcccCccCCCCCCccCCCcccCCCcCCcccCC'
m4 = 'cCCccCCccCCccCCccccCcCcCcCcCcCcCCCCccccCCCcCCcCCCC'
m5 = 'CCCcCcCcCcCCCcCCcCcCCccCcCCcccCccCCcCcCcCcCcccccCc'

# %%
'''
Acima, temos o resultado de 50 lançamentos de cada moeda (m1, m2, m3, m4 e m5), 
onde c representa a ocorrência do evento CARA e C representa a ocorrência do evento COROA.

Monte um Dataframe onde, Freq. C e Freq. c são, respectivamente, as frequências de COROAS e de CARAS em cada
teste.
'''

eventos = {'m1': list(m1), 
            'm2': list(m2), 
            'm3': list(m3), 
            'm4': list(m4), 
            'm5': list(m5)}
moedas = pd.DataFrame(eventos)
df = pd.DataFrame(data = ['Cara', 'Coroa'], 
                    index = ['c', 'C'], 
                    columns = ['Faces'])
for item in moedas:
    df = pd.concat([df, moedas[item].value_counts()], 
                    axis = 1)
df
# Out:
# /home/clayton/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#    Faces  m1  m2  m3  m4  m5
# C  Coroa  25  24  31  27  25
# c   Cara  25  26  19  23  25

# %%
# Dado o seguinte conjunto de dados:

imoveis = pd.DataFrame([['Apartamento', None, 970, 68], 
                        ['Apartamento', 2000, 878, 112], 
                        ['Casa', 5000, None, 500], 
                        ['Apartamento', None, 1010, 170], 
                        ['Apartamento', 1500, 850, None], 
                        ['Casa', None, None, None], 
                        ['Apartamento', 2000, 878, None], 
                        ['Apartamento', 1550, None, 228], 
                        ['Apartamento', 2500, 880, 195]], 
                        columns = ['Tipo', 'Valor', 'Condominio', 'IPTU'])

# %%
# Exer 1

imoveis.dropna(subset = ['Valor'], inplace = True)
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 4  Apartamento  1500.0       850.0    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 7  Apartamento  1550.0         NaN  228.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
# Exer2 (Verificar a questão do ~)

selecao = (imoveis['Tipo'] == 'Apartamento') & (imoveis['Condominio'].isnull())
imoveis = imoveis[~selecao]
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         NaN  500.0
# 4  Apartamento  1500.0       850.0    NaN
# 6  Apartamento  2000.0       878.0    NaN
# 8  Apartamento  2500.0       880.0  195.0

# %%
# Exer3

imoveis = imoveis.fillna({'Condominio': 0, 'IPTU': 0})
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 1  Apartamento  2000.0       878.0  112.0
# 2         Casa  5000.0         0.0  500.0
# 4  Apartamento  1500.0       850.0    0.0
# 6  Apartamento  2000.0       878.0    0.0
# 8  Apartamento  2500.0       880.0  195.0

# %%
# Exer4
imoveis.index = range(imoveis.shape[0])
imoveis
# Out:
#           Tipo   Valor  Condominio   IPTU
# 0  Apartamento  2000.0       878.0  112.0
# 1         Casa  5000.0         0.0  500.0
# 2  Apartamento  1500.0       850.0    0.0
# 3  Apartamento  2000.0       878.0    0.0
# 4  Apartamento  2500.0       880.0  195.0
